# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Seijsener\Ironhack\unit1\day3\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv')

# %%
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1 = pd.read_csv(r'C:\Users\Seijsener\Ironhack\unit1\day3\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv')

# %%
df1
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df2 = pd.read_csv(r'C:\Users\Seijsener\Ironhack\unit1\day3\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv')

# %%
df2
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df.shape
# Out:
# (4008, 11)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
print(df.head())
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
print(df.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
desired_order = ['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']
df = df[desired_order + list(df.columns.difference(desired_order))]
print(df)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data = pd.DataFrame(df)
data1 = pd.DataFrame(df1)
data2 = pd.DataFrame(df2)
def get_numerical_columns(df):
    return df.select_dtypes(include='number').columns
numerical_columns_df = get_numerical_columns(df)
numerical_columns_df1 = get_numerical_columns(df1)
numerical_columns_df2 = get_numerical_columns(df2)

print("Numerical columns in df:", numerical_columns_df)
print("Numerical columns in df1:", numerical_columns_df1)
print("Numerical columns in df2:", numerical_columns_df2)
# Out:
# Numerical columns in df: Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')
# Numerical columns in df1: Index(['Income', 'Monthly Premium Auto', 'Total Claim Amount'], dtype='object')
# Numerical columns in df2: Index(['Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Number of Open Complaints', 'Total Claim Amount'],
#       dtype='object')

# %%
def get_categorical_columns(df):
    return df.select_dtypes(include='object').columns

dataframes = [df, df1, df2]

for idx, df in enumerate(dataframes, start=1):
    categorical_columns = get_categorical_columns(df)
    print(f"Categorical columns in df{idx}:", categorical_columns)
# Out:
# Categorical columns in df1: Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'number_of_open_complaints', 'policy_type', 'vehicle_class'],
#       dtype='object')
# Categorical columns in df2: Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Number of Open Complaints', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Categorical columns in df3: Index(['Customer', 'State', 'Education', 'Gender', 'Policy Type',
#        'Vehicle Class'],
#       dtype='object')

# %%
concatenated_df = pd.concat([df, df1, df2], ignore_index=True)
print(concatenated_df)
# Out:
#       Customer       State Customer Lifetime Value             Education  \
# 0      SA25987  Washington             3479.137523  High School or Below
# 1      TB86706     Arizona             2502.637401                Master
# 2      ZL73902      Nevada             3265.156348              Bachelor
# 3      KX23516  California             4455.843406  High School or Below
# 4      FN77294  California              7704.95848  High School or Below
# ...        ...         ...                     ...                   ...
# 15131  LA72316  California             23405.98798              Bachelor
# 15132  PK87824  California             3096.511217               College
# 15133  TD14365  California             8163.890428              Bachelor
# 15134  UP19263  California             7524.442436               College
# 15135  Y167826  California             2611.836866               College
#
#       Gender  Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %% [markdown]
# #Understand the meaning of all columns

# %%
print(df.describe())
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              7070.000000   7070.000000           7070.000000
# mean               8028.803803  37333.857709             93.199010
# std                6942.419253  30349.879656             34.210682
# min                1898.007675      0.000000             61.000000
# 25%                3981.073024      0.000000             68.000000
# 50%                5782.095838  33557.500000             83.000000
# 75%                8989.995803  61895.500000            109.000000
# max               83325.381190  99961.000000            298.000000
#
#        Number of Open Complaints  Total Claim Amount
# count                7070.000000         7070.000000
# mean                    0.384300          436.215960
# std                     0.915658          291.236837
# min                     0.000000            0.099007
# 25%                     0.000000          274.363620
# ...

# %%
print(df.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
del df['Education']

# %%
del df['Number of Open Complaints']

# %%
print(df.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Gender', 'Income',
#        'Monthly Premium Auto', 'Policy Type', 'Total Claim Amount',
#        'Vehicle Class'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Customer                    object
# State                       object
# Customer Lifetime Value    float64
# Gender                      object
# Income                       int64
# Monthly Premium Auto         int64
# Policy Type                 object
# Total Claim Amount         float64
# Vehicle Class               object
# dtype: object

# %%
df['Customer Lifetime Value'] = df['Customer Lifetime Value'] / 100

# %%
print(df.dtypes)
# Out:
# Customer                    object
# State                       object
# Customer Lifetime Value    float64
# Gender                      object
# Income                       int64
# Monthly Premium Auto         int64
# Policy Type                 object
# Total Claim Amount         float64
# Vehicle Class               object
# dtype: object

# %%
duplicate_rows = df[df.duplicated()]
print(df[duplicate_rows])
df = df.drop_duplicates()
print(df)
# Out:
#      Customer State  Customer Lifetime Value Gender  Income  \
# 0         NaN   NaN                      NaN    NaN     NaN
# 1         NaN   NaN                      NaN    NaN     NaN
# 2         NaN   NaN                      NaN    NaN     NaN
# 3         NaN   NaN                      NaN    NaN     NaN
# 4         NaN   NaN                      NaN    NaN     NaN
# ...       ...   ...                      ...    ...     ...
# 7065      NaN   NaN                      NaN    NaN     NaN
# 7066      NaN   NaN                      NaN    NaN     NaN
# 7067      NaN   NaN                      NaN    NaN     NaN
# 7068      NaN   NaN                      NaN    NaN     NaN
# 7069      NaN   NaN                      NaN    NaN     NaN
#
#       Monthly Premium Auto Policy Type  Total Claim Amount Vehicle Class
# 0                      NaN         NaN                 NaN           NaN
# 1                      NaN         NaN                 NaN           NaN
# ...

# %%
filtered_df = df[df['Income'] <= 0]
print(filtered_df)
# Out:
#      Customer       State  Customer Lifetime Value Gender  Income  \
# 0     SA25987  Washington                34.791375      M       0
# 1     TB86706     Arizona                25.026374      M       0
# 3     KX23516  California                44.558434      F       0
# 6     FP59138      Oregon               130.241301      M       0
# 12    VG31922      Nevada                65.162149      F       0
# ...       ...         ...                      ...    ...     ...
# 7059  WZ45103  California                56.780502      F       0
# 7061  RX91025  California               198.722620      M       0
# 7062  AC13887  California                46.289953      M       0
# 7067  TD14365  California                81.638904      M       0
# 7069  Y167826  California                26.118369      M       0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                      104   Personal Auto          499.200000   Two-Door Car
# ...
